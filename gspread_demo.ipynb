# %% [markdown]
# <a href="https://colab.research.google.com/github/arguntolga/ts_jupyter/blob/main/gspread_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code example: Export World Happiness Report 2023 to Google Spreadsheet using Google Colab
#
# https://worldhappiness.report/data/
#
# ## Load XLS file with 2023 report data into Pandas Dataframe

# %%
import pandas as pd

# %%
complete_df = pd.read_excel("https://happiness-report.s3.amazonaws.com/2023/DataForFigure2.1WHR2023.xls")

# %%
df = complete_df.sort_values("Ladder score", ascending=False)[[
    "Country name", "Ladder score", "Logged GDP per capita", "Social support",
    "Healthy life expectancy", "Freedom to make life choices",
    "Generosity", "Perceptions of corruption"]]

df
# Out:
#          Country name  Ladder score  Logged GDP per capita  Social support  \
# 0             Finland        7.8042              10.792010        0.968770
# 1             Denmark        7.5864              10.962164        0.954112
# 2             Iceland        7.5296              10.895531        0.982533
# 3              Israel        7.4729              10.638705        0.943344
# 4         Netherlands        7.4030              10.942279        0.930499
# ..                ...           ...                    ...             ...
# 132  Congo (Kinshasa)        3.2072               7.006671        0.651610
# 133          Zimbabwe        3.2035               7.640998        0.689918
# 134      Sierra Leone        3.1376               7.394014        0.555251
# 135           Lebanon        2.3922               9.477677        0.529754
# 136       Afghanistan        1.8590               7.324032        0.341341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  71.149994                      0.961408   -0.018824
# 1                  71.250145                      0.933533    0.134242
# 2                  72.050018                      0.936349    0.210987
# 3                  72.697205                      0.808866   -0.023080
# 4                  71.550018                      0.886875    0.212686
# ..                       ...                           ...         ...
# 132                55.375000                      0.663798    0.085998
# 133                54.049889                      0.654055   -0.046230
# 134                54.899853                      0.660367    0.104929
# 135                66.148819                      0.473900   -0.140915
# 136                54.712410                      0.381642   -0.081011
#
#      Perceptions of corruption
# 0                     0.181745
# 1                     0.195814
# 2                     0.667848
# 3                     0.708094
# 4                     0.378929
# ..                         ...
# 132                   0.833752
# 133                   0.765582
# 134                   0.857780
# 135                   0.891104
# 136                   0.847215
#
# [137 rows x 8 columns]

# %% [markdown]
# ## Install gspread library
#
# gspread is a Python API for Google Sheets.
#
# https://docs.gspread.org/en/latest/

# %%
from google.colab import auth
from google.auth import default

try:
  import gspread
except ModuleNotFoundError:
  if 'google.colab' in str(get_ipython()):
    # %pip install gspread
  import gspread

# %% [markdown]
# ## Authenticate user to provide access to Google API

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %% [markdown]
# # Open spreadsheet
# You need to create new spreadsheet named "gspread-test" in your Google Drive

# %%
worksheet = gc.open("gspread-test")
sheet1 = worksheet.sheet1

# %% [markdown]
# copy dataframe data to Google Spreadsheet

# %%
sheet1.update([df.columns.values.tolist()] + df.fillna(-1).values.tolist())
# Out:
# {'spreadsheetId': '15f4zO_W-LZCwkAnmCnpD9vHJOz6aOdQC0fdQ938frOU',
#  'updatedRange': 'Sheet1!A1:H138',
#  'updatedRows': 138,
#  'updatedColumns': 8,
#  'updatedCells': 1104}

# %% [markdown]
# You can also set cell formulas. For example, add image to cell using `image() `function

# %%
sheet1.update('I1', '=image("https://upload.wikimedia.org/wikipedia/commons/8/85/Smiley.svg")', value_input_option='USER_ENTERED')
# Out:
# {'spreadsheetId': '15f4zO_W-LZCwkAnmCnpD9vHJOz6aOdQC0fdQ938frOU',
#  'updatedRange': 'Sheet1!I1',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# # Styling spreadsheet
# ## Setting column header styling
#
# Helper function to convert numeric column indexes into spread column name. For example column with index 3 should be converted into column "D". Thanks to sundar nataraj for providing [code snippet on Stack Overflow](https://stackoverflow.com/a/23862195/171847
# )

# %%
def index_to_spreadsheet_column(column_int, start_index=0):
  # https://stackoverflow.com/a/23862195/171847
  letter = ''
  while column_int > 25 + start_index:
      letter += chr(65 + int((column_int-start_index)/26) - 1)
      column_int = column_int - (int((column_int-start_index)/26))*26
  letter += chr(65 - start_index + (int(column_int)))
  return letter

print(index_to_spreadsheet_column(3))
# Out:
# D

# %% [markdown]
# find last column in spreadsheet

# %%
last_spreadsheet_column = index_to_spreadsheet_column(len(df.columns)-1)
last_spreadsheet_column
# Out:
# 'H'

# %% [markdown]
# format column headers with gray background end text in bold

# %%
sheet1.format(f"A1:{last_spreadsheet_column}1", {
    "backgroundColor": {
      "red": 100.0,
      "green": 100.0,
      "blue": 100.0
    },
    "horizontalAlignment": "CENTER",
    "textFormat": {
      "foregroundColor": {
        "red": 0.0,
        "green": 0.0,
        "blue": 0.0
      },
      "fontSize": 12,
      "bold": True,
    }
})
# Out:
# {'spreadsheetId': '15f4zO_W-LZCwkAnmCnpD9vHJOz6aOdQC0fdQ938frOU',
#  'replies': [{}]}

# %% [markdown]
# It would be nice to add background gradient to spreadsheet similar to what could be done in pandas

# %%
from matplotlib import pyplot

df.style.background_gradient(cmap=pyplot.get_cmap('Spectral')).format(precision=4)
# Out:
# <style type="text/css">
# #T_673a5_row0_col1, #T_673a5_row0_col5, #T_673a5_row2_col3, #T_673a5_row8_col2, #T_673a5_row23_col7, #T_673a5_row81_col4, #T_673a5_row83_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_673a5_row0_col2, #T_673a5_row12_col1, #T_673a5_row24_col5, #T_673a5_row26_col2, #T_673a5_row41_col2, #T_673a5_row44_col7, #T_673a5_row51_col3, #T_673a5_row56_col4, #T_673a5_row127_col7 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_673a5_row0_col3, #T_673a5_row5_col5, #T_673a5_row13_col2, #T_673a5_row76_col7, #T_673a5_row94_col7 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_673a5_row0_col4, #T_673a5_row10_col4, #T_673a5_row16_col5, #T_673a5_row32_col1, #T_673a5_row57_col4, #T_673a5_row69_col2 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_673a5_row0_col6, #T_673a5_row4_col7 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_673a5_row0_col7 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_673a5_row1_col1, #T_673a5_row62_col7 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_673a5_row1_col2, #T_673a5_row4_col2, #T_673a5_row9_col1, #T_673a5_row20_col3, #T_673a5_row22_col5, #T_673a5_row27_col5, #T_673a5_row29_col5, #T_673a5_row46_col4, #T_673a5_row50_col7 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_673a5_row1_col3, #T_673a5_row2_col1, #T_673a5_row2_col5, #T_673a5_row17_col3, #T_673a5_row28_col3, #T_673a5_row61_col5 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_673a5_row1_col4, #T_673a5_row13_col4, #T_673a5_row15_col4, #T_673a5_row55_col4, #T_673a5_row92_col7, #T_673a5_row100_col7 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_673a5_row1_col5, #T_673a5_row9_col3, #T_673a5_row21_col3, #T_673a5_row74_col7, #T_673a5_row135_col7 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_673a5_row1_col6 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_673a5_row1_col7 {
#   background-color: #c1274a;
#   color: #f1f1f1;
# }
# #T_673a5_row2_col2, #T_673a5_row7_col5, #T_673a5_row10_col2, #T_673a5_row11_col5, #T_673a5_row65_col5, #T_673a5_row71_col7, #T_673a5_row73_col7, #T_673a5_row132_col7 {
#   background-color: #3d95b8;
#   color: #f1f1f1;
# }
# #T_673a5_row2_col4, #T_673a5_row15_col5, #T_673a5_row21_col7, #T_673a5_row22_col1, #T_673a5_row32_col4, #T_673a5_row39_col3, #T_673a5_row44_col5, #T_673a5_row50_col2, #T_673a5_row55_col2, #T_673a5_row103_col7, #T_673a5_row117_col5 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_673a5_row2_col6, #T_673a5_row45_col5, #T_673a5_row67_col2, #T_673a5_row113_col3 {
#   background-color: #e8f69b;
#   color: #000000;
# }
# #T_673a5_row2_col7, #T_673a5_row61_col1, #T_673a5_row62_col1, #T_673a5_row63_col1, #T_673a5_row63_col4, #T_673a5_row70_col2, #T_673a5_row78_col2, #T_673a5_row100_col2, #T_673a5_row105_col4 {
#   background-color: #bfe5a0;
#   color: #000000;
# }
# #T_673a5_row3_col1, #T_673a5_row30_col3, #T_673a5_row30_col5 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_673a5_row3_col2, #T_673a5_row32_col2 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_673a5_row3_col3, #T_673a5_row6_col3, #T_673a5_row50_col3, #T_673a5_row106_col7, #T_673a5_row118_col7 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_673a5_row3_col4, #T_673a5_row19_col2, #T_673a5_row123_col7 {
#   background-color: #5ab4ab;
#   color: #f1f1f1;
# }
# #T_673a5_row3_col5, #T_673a5_row27_col2, #T_673a5_row43_col7, #T_673a5_row77_col5 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_673a5_row3_col6, #T_673a5_row130_col3, #T_673a5_row135_col3, #T_673a5_row136_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_673a5_row3_col7, #T_673a5_row22_col4, #T_673a5_row45_col1, #T_673a5_row46_col1, #T_673a5_row47_col1, #T_673a5_row48_col1, #T_673a5_row49_col1 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_673a5_row4_col1, #T_673a5_row5_col1, #T_673a5_row5_col3, #T_673a5_row19_col3, #T_673a5_row67_col7, #T_673a5_row83_col7, #T_673a5_row97_col7 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_673a5_row4_col3, #T_673a5_row7_col2, #T_673a5_row8_col5, #T_673a5_row31_col3, #T_673a5_row33_col7, #T_673a5_row43_col3 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_673a5_row4_col4, #T_673a5_row27_col1, #T_673a5_row36_col4, #T_673a5_row37_col2, #T_673a5_row105_col2 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_673a5_row4_col5, #T_673a5_row5_col2, #T_673a5_row15_col2, #T_673a5_row40_col7, #T_673a5_row104_col7, #T_673a5_row124_col7, #T_673a5_row131_col7 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_673a5_row4_col6, #T_673a5_row61_col4, #T_673a5_row116_col5 {
#   background-color: #e7f59a;
#   color: #000000;
# }
# #T_673a5_row5_col4, #T_673a5_row38_col2, #T_673a5_row58_col7, #T_673a5_row62_col3, #T_673a5_row80_col3, #T_673a5_row125_col7 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_673a5_row5_col6, #T_673a5_row53_col4, #T_673a5_row62_col4, #T_673a5_row93_col1 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_673a5_row5_col7, #T_673a5_row55_col6 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_673a5_row6_col1, #T_673a5_row12_col3, #T_673a5_row21_col5, #T_673a5_row25_col2 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_673a5_row6_col2, #T_673a5_row36_col3, #T_673a5_row112_col7, #T_673a5_row114_col7, #T_673a5_row134_col7 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_673a5_row6_col4, #T_673a5_row28_col1, #T_673a5_row29_col1, #T_673a5_row57_col2, #T_673a5_row79_col5, #T_673a5_row87_col3 {
#   background-color: #76c8a5;
#   color: #000000;
# }
# #T_673a5_row6_col5, #T_673a5_row59_col7 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_673a5_row6_col6, #T_673a5_row103_col3, #T_673a5_row106_col2, #T_673a5_row106_col6 {
#   background-color: #ffffbe;
#   color: #000000;
# }
# #T_673a5_row6_col7, #T_673a5_row74_col6, #T_673a5_row80_col6 {
#   background-color: #eb6046;
#   color: #f1f1f1;
# }
# #T_673a5_row7_col1, #T_673a5_row7_col3, #T_673a5_row8_col1 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_673a5_row7_col4, #T_673a5_row17_col2, #T_673a5_row18_col1, #T_673a5_row44_col3, #T_673a5_row45_col2, #T_673a5_row46_col2, #T_673a5_row53_col3, #T_673a5_row59_col3, #T_673a5_row105_col7 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_673a5_row7_col6, #T_673a5_row112_col2, #T_673a5_row123_col4, #T_673a5_row125_col4, #T_673a5_row127_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_673a5_row7_col7, #T_673a5_row37_col6, #T_673a5_row98_col6, #T_673a5_row103_col4 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_673a5_row8_col3, #T_673a5_row9_col2, #T_673a5_row17_col1, #T_673a5_row24_col3, #T_673a5_row36_col2, #T_673a5_row55_col3, #T_673a5_row68_col5, #T_673a5_row69_col7, #T_673a5_row91_col3 {
#   background-color: #52abae;
#   color: #f1f1f1;
# }
# #T_673a5_row8_col4, #T_673a5_row23_col2, #T_673a5_row33_col3, #T_673a5_row41_col3, #T_673a5_row47_col2, #T_673a5_row54_col7, #T_673a5_row64_col7 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_673a5_row8_col6, #T_673a5_row121_col6 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_673a5_row8_col7, #T_673a5_row108_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_673a5_row9_col4, #T_673a5_row40_col1, #T_673a5_row42_col3, #T_673a5_row56_col3, #T_673a5_row68_col3 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_673a5_row9_col5, #T_673a5_row36_col5 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_673a5_row9_col6, #T_673a5_row49_col4, #T_673a5_row89_col1, #T_673a5_row96_col3, #T_673a5_row100_col6, #T_673a5_row103_col5, #T_673a5_row110_col3, #T_673a5_row133_col3 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_673a5_row9_col7, #T_673a5_row26_col6, #T_673a5_row135_col5 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_673a5_row10_col1, #T_673a5_row11_col1, #T_673a5_row13_col3, #T_673a5_row42_col7, #T_673a5_row65_col3, #T_673a5_row84_col3, #T_673a5_row98_col7 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_673a5_row10_col3, #T_673a5_row12_col2, #T_673a5_row34_col3, #T_673a5_row39_col5, #T_673a5_row51_col7, #T_673a5_row54_col5, #T_673a5_row58_col3, #T_673a5_row66_col3, #T_673a5_row69_col3 {
#   background-col

# %%
import matplotlib
import numpy as np

# https://scipy-cookbook.readthedocs.io/items/Matplotlib_ColormapTransformations.html
def cmap_map(function, cmap):
    """ Applies function (which should operate on vectors of shape 3: [r, g, b]), on colormap cmap.
    This routine will break any discontinuous points in a colormap.
    """
    cdict = cmap._segmentdata
    step_dict = {}
    # Firt get the list of points where the segments start or end
    for key in ('red', 'green', 'blue'):
        step_dict[key] = list(map(lambda x: x[0], cdict[key]))
    step_list = sum(step_dict.values(), [])
    step_list = np.array(list(set(step_list)))
    # Then compute the LUT, and apply the function to the LUT
    reduced_cmap = lambda step : np.array(cmap(step)[0:3])
    old_LUT = np.array(list(map(reduced_cmap, step_list)))
    new_LUT = np.array(list(map(function, old_LUT)))
    # Now try to make a minimal segment definition of the new LUT
    cdict = {}
    for i, key in enumerate(['red','green','blue']):
        this_cdict = {}
        for j, step in enumerate(step_list):
            if step in step_dict[key]:
                this_cdict[step] = new_LUT[j, i]
            elif new_LUT[j,i] != old_LUT[j, i]:
                this_cdict[step] = new_LUT[j, i]
        colorvector = list(map(lambda x: x + (x[1], ), this_cdict.items()))
        colorvector.sort()
        cdict[key] = colorvector

    return matplotlib.colors.LinearSegmentedColormap('colormap',cdict,1024)

# %%
from matplotlib import colors

spectral_cmap = pyplot.get_cmap('Spectral')
light_spectral_cmap = cmap_map(lambda x: x/2 + 0.5, spectral_cmap)

formats = []
for col_index in range(1, len(df.columns)): #len(df.columns)-1):
  col = df.iloc[:, col_index]
  min_value = col.min()
  max_value = col.max()
  norm = colors.Normalize(vmin=min_value, vmax=max_value, clip=True)

  idx = 2

  for value in col:
    normanized_value = norm(value)
    cell_id = f"{index_to_spreadsheet_column(col_index)}{idx}"
    color = light_spectral_cmap(normanized_value)
    formats.append({
        "range": f"{cell_id}:{cell_id}",
        "format": {
            "backgroundColor": {
              "red": color[0],
              "green": color[1],
              "blue": color[2]
            }
        }
    })
    idx += 1

  batch_format_response = sheet1.batch_format(formats)

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of          Country name  Ladder score  Logged GDP per capita  Social support  \
# 0             Finland        7.8042              10.792010        0.968770
# 1             Denmark        7.5864              10.962164        0.954112
# 2             Iceland        7.5296              10.895531        0.982533
# 3              Israel        7.4729              10.638705        0.943344
# 4         Netherlands        7.4030              10.942279        0.930499
# ..                ...           ...                    ...             ...
# 132  Congo (Kinshasa)        3.2072               7.006671        0.651610
# 133          Zimbabwe        3.2035               7.640998        0.689918
# 134      Sierra Leone        3.1376               7.394014        0.555251
# 135           Lebanon        2.3922               9.477677        0.529754
# 136       Afghanistan        1.8590               7.324032        0.341341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  71.149994                      0.961408   -0.018824
# 1                  71.250145                      0.933533    0.134242
# 2                  72.050018                      0.936349    0.210987
# 3                  72.697205                      0.808866   -0.023080
# 4                  71.550018                      0.886875    0.212686
# ..                       ...                           ...         ...
# 132                55.375000                      0.663798    0.085998
# 133                54.049889                      0.654055   -0.046230
# 134                54.899853                      0.660367    0.104929
# 135                66.148819                      0.473900   -0.140915
# 136                54.712410                      0.381642   -0.081011
#
#      Perceptions of corruption
# 0                     0.181745
# 1                     0.195814
# 2                     0.667848
# 3                     0.708094
# 4                     0.378929
# ..                         ...
# 132                   0.833752
# 133                   0.765582
# 134                   0.857780
# 135                   0.891104
# 136                   0.847215
#
# [137 rows x 8 columns]>
