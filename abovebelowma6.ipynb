# %% [markdown]
# <a href="https://colab.research.google.com/github/arguntolga/ts_jupyter/blob/main/abovebelowma6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import pandas.api.types as pdtypes
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Define your two stock tickers
#stock_list = ["EREGL.IS", "FROTO.IS", "THYAO.IS", "TTRAK.IS", "MIATK.IS"]
stock_list = [
    "AKBNK.IS", "ARCLK.IS", "ASELS.IS", "BIMAS.IS", "BRISA.IS", "ASTOR.IS",
    "DOHOL.IS", "SASA.IS", "EKGYO.IS", "ENKAI.IS", "EREGL.IS", "FROTO.IS",
    "GARAN.IS", "GUBRF.IS", "HALKB.IS", "HEKTS.IS", "ISCTR.IS", "KCHOL.IS",
    "KOZAA.IS", "KOZAL.IS", "KRDMD.IS", "MGROS.IS", "TTRAK.IS", "PETKM.IS",
    "PGSUS.IS", "SAHOL.IS", "SISE.IS", "TAVHL.IS", "THYAO.IS", "TKFEN.IS",
    "TTKOM.IS", "TUPRS.IS", "ULKER.IS", "VESTL.IS", "YKBNK.IS", "VESBE.IS",
    "ALFAS.IS", "TCELL.IS", "ALARK.IS", "TKNSA.IS", "KONYA.IS", "AKSA.IS",
    "AKSEN.IS", "YEOTK.IS", "GESAN.IS", "EUPWR.IS", "CWENE.IS", "YYLGD.IS",
    "MAVI.IS", "ELITE.IS", "TOASO.IS", "SMRTG.IS", "ERBOS.IS", "ARDYZ.IS",
    "GWIND.IS", "JANTS.IS", "LOGO.IS", "SUWEN.IS", "ULUUN.IS", "KAREL.IS"
]

# Set start and end dates
start_date = "2023-05-04"
end_date = "2024-08-03"

# Download data using yfinance
data = yf.download(stock_list, start=start_date, end=end_date)["Adj Close"]
data = data.fillna(0)
#display(data)

def calculate_moving_averages(stock_list, data, window_sizes):
  for stock in stock_list:
    for window in window_sizes:
      data[stock + '_MA_' + str(window)] = data[stock].rolling(window=window).mean()
  return data

def calculate_above_below_ma(stock_list, data, window_sizes):
  above_below_counts = {}
  for date in data.index:
    daily_counts = {}
    for window in window_sizes:
      above_count = 0
      for stock in stock_list:
        ma_col = f"{stock}_MA_{window}"
        above_count += (data.loc[date, stock] > data.loc[date, ma_col])
      below_count = len(stock_list) - above_count
      daily_counts["Above MA" + str(window)] = above_count
      daily_counts["Below MA" + str(window)] = below_count
      daily_counts["Ratio MA" + str(window)] = above_count / max(1,below_count)
    above_below_counts[date] = daily_counts
  return pd.DataFrame(above_below_counts).transpose()


def calculate_super_stock(stock_list, data, window_sizes):
  super_stock = 0
  super_stock_df = pd.DataFrame(index=data.index, columns=stock_list)
  for date in data.index:
    for stock in stock_list:
      super_stock_level = 0
      if data.loc[date, stock] > data.loc[date, f"{stock}_MA_{window_sizes[0]}"]:
          super_stock_level += 1
      for window_idx in range(len(window_sizes) - 1):
        current_ma_col = f"{stock}_MA_{window_sizes[window_idx]}"
        next_ma_col = f"{stock}_MA_{window_sizes[window_idx + 1]}"
        if data.loc[date, current_ma_col] > data.loc[date, next_ma_col]:
          super_stock_level += 1
      super_stock_df.loc[date, stock] = int(super_stock_level)
  return super_stock_df


# Define window sizes for moving averages
window_sizes = [10, 20, 50, 100, 200]

# Apply the moving average calculation
data_with_ma = calculate_moving_averages(stock_list, data.copy(), window_sizes)
data_with_ma = data_with_ma.fillna(0)
#display(data_with_ma)

def drop_oldest_rows(data, n_rows_to_drop):
  # Sort by index (assuming it's a date index)
  data_sorted = data.sort_index()
  # Select and drop the oldest N rows using iloc (integer location based indexing)
  data_dropped = data_sorted.iloc[n_rows_to_drop:]
  return data_dropped

data_dropped_ma = drop_oldest_rows(data_with_ma.copy(), 200)

# Calculate above/below MA counts
above_below_data = calculate_above_below_ma(stock_list, data_dropped_ma.copy(), window_sizes)
#print(above_below_data)

def green_red(value):
    if value < 1:
        return 'color: red; font-weight: bold'
    elif value > 2:
        return 'color: green; font-weight: bold'
    else:
        return None

above_below_reversed = above_below_data.iloc[::-1]
#above_below_reversed.style.applymap(green_red)

def convert_to_int_if_zero_fraction(df):
  # Select numeric columns only (avoid errors with non-numeric data)
  numeric_cols = df.select_dtypes(include=[np.number])
  for col in numeric_cols:
    # Apply conversion function to the selected numeric column
    df[col] = df[col].apply(lambda x: int(x) if isinstance(x, (int, float)) and x % 1 == 0 else x)
  return df

# Apply conversion to all numeric columns
above_below_reversed = convert_to_int_if_zero_fraction(above_below_reversed.copy())  # Operate on a copy to avoid modifying original data

# Assuming 'Date' is the index (set as index if needed: df.set_index('Date'))
above_below_reversed.plot.line(y=['Ratio MA10', 'Ratio MA20', 'Ratio MA50', 'Ratio MA100', 'Ratio MA200'], figsize=(16, 10))  # Adjust figsize for customization
plt.title("Total Ratio MA10")
plt.xlabel("Date")
plt.ylabel("Value")
plt.grid(True)  # Add grid lines for better readability (optional)
plt.show()

def ratio_subset(window_sizes):
   ratio_column_array = []
   for window in window_sizes:
     ratio_column_array.append("Ratio MA" + str(window))
   return ratio_column_array

above_below_reversed.style.applymap(green_red, subset = ratio_subset(window_sizes))



#display(above_below_data.iloc[::-1])

#super_stock_data = calculate_super_stock(stock_list, data_dropped_ma, window_sizes)
#cm = sns.light_palette("green", as_cmap=True)
#super_stock_data.iloc[::-1].apply(pd.to_numeric).style.set_sticky(axis=1).background_gradient(cmap=cm)
# Out:
# [*********************100%%**********************]  60 of 60 completed
# <style type="text/css">
# #T_cfef9_row0_col2, #T_cfef9_row0_col5, #T_cfef9_row1_col2, #T_cfef9_row1_col5, #T_cfef9_row2_col2, #T_cfef9_row2_col5, #T_cfef9_row3_col2, #T_cfef9_row3_col5, #T_cfef9_row4_col2, #T_cfef9_row4_col5, #T_cfef9_row5_col2, #T_cfef9_row5_col5, #T_cfef9_row6_col2, #T_cfef9_row6_col5, #T_cfef9_row7_col2, #T_cfef9_row16_col2, #T_cfef9_row17_col2, #T_cfef9_row18_col2, #T_cfef9_row37_col2, #T_cfef9_row37_col5, #T_cfef9_row37_col8, #T_cfef9_row37_col11, #T_cfef9_row37_col14, #T_cfef9_row40_col2, #T_cfef9_row40_col5, #T_cfef9_row40_col8, #T_cfef9_row41_col2, #T_cfef9_row41_col5, #T_cfef9_row41_col8, #T_cfef9_row41_col11, #T_cfef9_row42_col2, #T_cfef9_row42_col5, #T_cfef9_row42_col8, #T_cfef9_row43_col2, #T_cfef9_row43_col5, #T_cfef9_row43_col8, #T_cfef9_row44_col5, #T_cfef9_row44_col8, #T_cfef9_row45_col2, #T_cfef9_row45_col5, #T_cfef9_row45_col8, #T_cfef9_row46_col2, #T_cfef9_row46_col5, #T_cfef9_row46_col8, #T_cfef9_row47_col2, #T_cfef9_row47_col5, #T_cfef9_row47_col8, #T_cfef9_row48_col2, #T_cfef9_row48_col5, #T_cfef9_row48_col8, #T_cfef9_row49_col2, #T_cfef9_row49_col5, #T_cfef9_row49_col8, #T_cfef9_row50_col2, #T_cfef9_row50_col5, #T_cfef9_row51_col2, #T_cfef9_row51_col5, #T_cfef9_row52_col2, #T_cfef9_row52_col5, #T_cfef9_row53_col2, #T_cfef9_row53_col5, #T_cfef9_row53_col8, #T_cfef9_row54_col2, #T_cfef9_row54_col5, #T_cfef9_row55_col2, #T_cfef9_row55_col5, #T_cfef9_row56_col2, #T_cfef9_row56_col5, #T_cfef9_row57_col2, #T_cfef9_row57_col5, #T_cfef9_row58_col2, #T_cfef9_row58_col5, #T_cfef9_row59_col5, #T_cfef9_row60_col2, #T_cfef9_row60_col5, #T_cfef9_row61_col2, #T_cfef9_row61_col5, #T_cfef9_row62_col2, #T_cfef9_row62_col5, #T_cfef9_row63_col2, #T_cfef9_row63_col5, #T_cfef9_row64_col2, #T_cfef9_row64_col5, #T_cfef9_row65_col2, #T_cfef9_row66_col2, #T_cfef9_row66_col5, #T_cfef9_row67_col2 {
#   color: red;
#   font-weight: bold;
# }
# #T_cfef9_row0_col14, #T_cfef9_row1_col14, #T_cfef9_row2_col14, #T_cfef9_row3_col14, #T_cfef9_row4_col14, #T_cfef9_row5_col11, #T_cfef9_row5_col14, #T_cfef9_row6_col11, #T_cfef9_row6_col14, #T_cfef9_row7_col8, #T_cfef9_row7_col11, #T_cfef9_row7_col14, #T_cfef9_row8_col8, #T_cfef9_row8_col11, #T_cfef9_row8_col14, #T_cfef9_row9_col8, #T_cfef9_row9_col11, #T_cfef9_row9_col14, #T_cfef9_row10_col2, #T_cfef9_row10_col5, #T_cfef9_row10_col8, #T_cfef9_row10_col11, #T_cfef9_row10_col14, #T_cfef9_row11_col2, #T_cfef9_row11_col5, #T_cfef9_row11_col8, #T_cfef9_row11_col11, #T_cfef9_row11_col14, #T_cfef9_row12_col2, #T_cfef9_row12_col5, #T_cfef9_row12_col8, #T_cfef9_row12_col11, #T_cfef9_row12_col14, #T_cfef9_row13_col2, #T_cfef9_row13_col5, #T_cfef9_row13_col8, #T_cfef9_row13_col11, #T_cfef9_row13_col14, #T_cfef9_row14_col5, #T_cfef9_row14_col8, #T_cfef9_row14_col11, #T_cfef9_row14_col14, #T_cfef9_row15_col8, #T_cfef9_row15_col11, #T_cfef9_row15_col14, #T_cfef9_row16_col11, #T_cfef9_row16_col14, #T_cfef9_row17_col11, #T_cfef9_row17_col14, #T_cfef9_row18_col5, #T_cfef9_row18_col11, #T_cfef9_row18_col14, #T_cfef9_row19_col5, #T_cfef9_row19_col8, #T_cfef9_row19_col11, #T_cfef9_row19_col14, #T_cfef9_row20_col5, #T_cfef9_row20_col8, #T_cfef9_row20_col11, #T_cfef9_row20_col14, #T_cfef9_row21_col2, #T_cfef9_row21_col5, #T_cfef9_row21_col8, #T_cfef9_row21_col11, #T_cfef9_row21_col14, #T_cfef9_row22_col2, #T_cfef9_row22_col5, #T_cfef9_row22_col8, #T_cfef9_row22_col11, #T_cfef9_row22_col14, #T_cfef9_row23_col2, #T_cfef9_row23_col5, #T_cfef9_row23_col8, #T_cfef9_row23_col11, #T_cfef9_row23_col14, #T_cfef9_row24_col2, #T_cfef9_row24_col5, #T_cfef9_row24_col8, #T_cfef9_row24_col11, #T_cfef9_row24_col14, #T_cfef9_row25_col2, #T_cfef9_row25_col5, #T_cfef9_row25_col8, #T_cfef9_row25_col11, #T_cfef9_row25_col14, #T_cfef9_row26_col2, #T_cfef9_row26_col5, #T_cfef9_row26_col11, #T_cfef9_row26_col14, #T_cfef9_row27_col2, #T_cfef9_row27_col5, #T_cfef9_row27_col8, #T_cfef9_row27_col11, #T_cfef9_row27_col14, #T_cfef9_row28_col2, #T_cfef9_row28_col5, #T_cfef9_row28_col8, #T_cfef9_row28_col11, #T_cfef9_row28_col14, #T_cfef9_row29_col2, #T_cfef9_row29_col5, #T_cfef9_row29_col8, #T_cfef9_row29_col11, #T_cfef9_row29_col14, #T_cfef9_row30_col2, #T_cfef9_row30_col5, #T_cfef9_row30_col8, #T_cfef9_row30_col11, #T_cfef9_row30_col14, #T_cfef9_row31_col2, #T_cfef9_row31_col5, #T_cfef9_row31_col11, #T_cfef9_row31_col14, #T_cfef9_row32_col2, #T_cfef9_row32_col5, #T_cfef9_row32_col11, #T_cfef9_row32_col14, #T_cfef9_row33_col2, #T_cfef9_row33_col5, #T_cfef9_row33_col11, #T_cfef9_row34_col2, #T_cfef9_row34_col5, #T_cfef9_row34_col11, #T_cfef9_row34_col14, #T_cfef9_row35_col2, #T_cfef9_row35_col5, #T_cfef9_row35_col11, #T_cfef9_row35_col14, #T_cfef9_row36_col2, #T_cfef9_row36_col5, #T_cfef9_row36_col11, #T_cfef9_row36_col14, #T_cfef9_row38_col2, #T_cfef9_row38_col5, #T_cfef9_row38_col11, #T_cfef9_row38_col14, #T_cfef9_row39_col2, #T_cfef9_row39_col5, #T_cfef9_row48_col14, #T_cfef9_row49_col11, #T_cfef9_row49_col14, #T_cfef9_row50_col11, #T_cfef9_row50_col14, #T_cfef9_row51_col11, #T_cfef9_row51_col14, #T_cfef9_row52_col11, #T_cfef9_row52_col14, #T_cfef9_row53_col11, #T_cfef9_row54_col11, #T_cfef9_row54_col14, #T_cfef9_row55_col11, #T_cfef9_row55_col14, #T_cfef9_row56_col11, #T_cfef9_row56_col14, #T_cfef9_row57_col8, #T_cfef9_row57_col11, #T_cfef9_row57_col14, #T_cfef9_row58_col8, #T_cfef9_row58_col11, #T_cfef9_row58_col14, #T_cfef9_row59_col8, #T_cfef9_row59_col11, #T_cfef9_row59_col14, #T_cfef9_row60_col8, #T_cfef9_row60_col11, #T_cfef9_row60_col14, #T_cfef9_row61_col11, #T_cfef9_row61_col14, #T_cfef9_row62_col8, #T_cfef9_row62_col11, #T_cfef9_row62_col14, #T_cfef9_row63_col8, #T_cfef9_row63_col11, #T_cfef9_row63_col14, #T_cfef9_row64_col8, #T_cfef9_row64_col11, #T_cfef9_row64_col14, #T_cfef9_row65_col8, #T_cfef9_row65_col11, #T_cfef9_row65_col14, #T_cfef9_row66_col8, #T_cfef9_row66_col11, #T_cfef9_row66_col14, #T_cfef9_row67_col8, #T_cfef9_row67_col11, #T_cfef9_row67_col14, #T_c ...
#   color: green;
#   font-weight: bold;
# }
# </style>
# <table id="T_cfef9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfef9_level0_col0" class="col_heading level0 col0" >Above MA10</th>
#       <th id="T_cfef9_level0_col1" class="col_heading level0 col1" >Below MA10</th>
#       <th id="T_cfef9_level0_col2" class="col_heading level0 col2" >Ratio MA10</th>
#       <th id="T_cfef9_level0_col3" class="col_heading level0 col3" >Above MA20</th>
#       <th id="T_cfef9_level0_col4" class="col_heading level0 col4" >Below MA20</th>
#       <th id="T_cfef9_level0_col5" class="col_heading level0 col5" >Ratio MA20</th>
#       <th id="T_cfef9_level0_col6" class="col_heading level0 col6" >Above MA50</th>
#       <th id="T_cfef9_level0_col7" class="col_heading level0 col7" >Below MA50</th>
#       <th id="T_cfef9_level0_col8" class="col_heading level0 col8" >Ratio MA50</th>
#       <th id="T_cfef9_level0_col9" class="col_heading level0 col9" >Above MA100</th>
#       <th id="T_cfef9_level0_col10" class="col_heading level0 col10" >Below MA100</th>
#       <th id="T_cfef9_level0_col11" class="col_heading level0 col11" >Ratio MA100</th>
#       <th id="T_cfef9_level0_col12" class="col_heading level0 col12" >Above MA200</th>
#       <th id="T_cfef9_level0_col13" class="col_heading level0 col13" >Below MA200</th>
#       <th id="T_cfef9_level0_col14" class="col_heading level0 col14" >Ratio MA20
